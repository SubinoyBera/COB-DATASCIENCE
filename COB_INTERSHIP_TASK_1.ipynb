# %%
import pandas as pd
import requests

# %%
api_data= requests.get("https://data.binance.com/api/v3/ticker/24hr")

# %%
data= api_data.json()

# %%
df= pd.DataFrame(data)

# %%
df.head()
# Out:
#     symbol priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC  0.00029000              0.472       0.06149717     0.06143000
# 1   LTCBTC  0.00011900              5.008       0.00243413     0.00237600
# 2   BNBBTC  0.00007100              0.887       0.00803221     0.00800100
# 3   NEOBTC  0.00000280              1.012       0.00027659     0.00027690
# 4  QTUMETH  0.00003800              2.872       0.00135281     0.00133700
#
#     lastPrice     lastQty    bidPrice        bidQty    askPrice  ...  \
# 0  0.06172000  0.07020000  0.06171000   26.09400000  0.06172000  ...
# 1  0.00249500  6.09400000  0.00249500  179.34500000  0.00249600  ...
# 2  0.00807200  0.09100000  0.00807200    3.95200000  0.00807300  ...
# 3  0.00027950  1.72000000  0.00027950   33.99000000  0.00027980  ...
# 4  0.00136100  8.80000000  0.00136100   89.20000000  0.00136700  ...
#
#     openPrice   highPrice    lowPrice          volume   quoteVolume  \
# ...

# %%
df.to_csv("C:\\Users\\SUBINOY\\Documents\\Binance_dataset.csv")
